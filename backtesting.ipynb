# %%
import numpy as np
import pandas as pd

from backtesting import Strategy
from backtesting.lib import crossover

from backtesting import Backtest

from scripts.data_preparation import load_trades_from_csv, get_bar_stats

import pickle
# Out:
# C:\Users\SnakeRZR\Desktop\projects\trading\env\lib\site-packages\backtesting\_plotting.py:50: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support (e.g. PyCharm, Spyder IDE). Reset with `backtesting.set_bokeh_output(notebook=False)`.
#   warnings.warn('Jupyter Notebook detected. '
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
path = 'data/trades_RIU2@FORTS_2022_08_19_2022_08_19.csv'
trades = load_trades_from_csv(path)
# display(trades)
# trades.info()
# display('Duplicates count',trades.duplicated().sum())

# %%
resampled = trades.set_index('datetime').groupby(pd.Grouper(freq='1Min'))
# time_bars = get_bar_stats(resampled)
one_minute_bar = get_bar_stats(resampled)
one_minute_bar = one_minute_bar.dropna()

# %%
one_minute_bar
# Out:
#                          open      high       low     close  vwap  volume  txn
# datetime
# 2022-08-19 10:00:00  111670.0  111970.0  111300.0  111700.0     0    1455  832
# 2022-08-19 10:01:00  111700.0  111850.0  111580.0  111670.0     0     731  466
# 2022-08-19 10:02:00  111670.0  111670.0  111400.0  111520.0     0     715  413
# 2022-08-19 10:03:00  111530.0  111730.0  111360.0  111430.0     0     636  440
# 2022-08-19 10:04:00  111450.0  111670.0  111210.0  111250.0     0    1014  563
# ...                       ...       ...       ...       ...   ...     ...  ...
# 2022-08-19 23:45:00  112480.0  112480.0  112450.0  112470.0     0      23   12
# 2022-08-19 23:46:00  112470.0  112490.0  112450.0  112490.0     0      31   14
# 2022-08-19 23:47:00  112490.0  112490.0  112430.0  112440.0     0      32    7
# 2022-08-19 23:48:00  112470.0  112520.0  112430.0  112430.0     0      96   56
# 2022-08-19 23:49:00  112510.0  112600.0  112390.0  112590.0     0     162  104
#
# [794 rows x 7 columns]

# %% [markdown]
# Is 1 minute grouping correct? Is minute 10:00:00 consists of all trades from 10:00:00 to 10:00:59.999? Is it the correct way to build bars?

# %%
path = 'data/trades_RIU2@FORTS_2022_08_23_2022_08_23.csv'
trades_valid = load_trades_from_csv(path)
# display(trades_valid)
# trades_valid.info()
# display('Duplicates count',trades_valid.duplicated().sum())
resampled_valid = trades_valid.set_index('datetime').groupby(pd.Grouper(freq='1Min'))
one_minute_bar_valid = get_bar_stats(resampled_valid)
one_minute_bar_valid = one_minute_bar_valid.dropna()

# %%
data = pd.concat([one_minute_bar,one_minute_bar_valid])
data.columns = ['Open','High','Low','Close','VWAP','Volume','Txn']

# %%
data
# Out:
#                          Open      High       Low     Close  VWAP  Volume  Txn
# datetime
# 2022-08-19 10:00:00  111670.0  111970.0  111300.0  111700.0     0    1455  832
# 2022-08-19 10:01:00  111700.0  111850.0  111580.0  111670.0     0     731  466
# 2022-08-19 10:02:00  111670.0  111670.0  111400.0  111520.0     0     715  413
# 2022-08-19 10:03:00  111530.0  111730.0  111360.0  111430.0     0     636  440
# 2022-08-19 10:04:00  111450.0  111670.0  111210.0  111250.0     0    1014  563
# ...                       ...       ...       ...       ...   ...     ...  ...
# 2022-08-23 23:45:00  114800.0  114820.0  114800.0  114820.0     0      15    8
# 2022-08-23 23:46:00  114820.0  114850.0  114820.0  114850.0     0      13    7
# 2022-08-23 23:47:00  114840.0  114880.0  114820.0  114880.0     0      29   19
# 2022-08-23 23:48:00  114820.0  114850.0  114820.0  114820.0     0       4    4
# 2022-08-23 23:49:00  114840.0  114850.0  114750.0  114750.0     0      27   18
#
# [1577 rows x 7 columns]

# %% [markdown]
# https://kernc.github.io/backtesting.py/doc/examples/Trading%20with%20Machine%20Learning.html

# %% [markdown]
# Let's create a class.
#
# We can use pretrained models, train model on first n bars, train model iteratively.
#
# Let's hypothesize that intraday activity has a limited number of states with different degrees of intensity. Whatever states and whatever nature of intensity. I'm simply trying to make a case for a pretrained model.
# So let's use pretrained model.

# %%
def SMA(values, n):
    """
    Return simple moving average of `values`, at
    each step taking into account `n` previous values.
    """
    return pd.Series(values).rolling(n).mean()

# %%
class MLStrategy(Strategy):
    up_threshold = 0.1
    down_threshold = 0.9
    
    tp = 100
    sl = 50
    
    def init(self):
        with open('model/logreg.pkl','rb') as f:
            self.up_model = pickle.load(f)
            
        with open('model/lgbm_model.pkl','rb') as f:
            self.down_model = pickle.load(f)
        
    def next(self):
        # print(self.data.df)
        data = self.data.df.iloc[-1:]
        # print(data)
        # print(data.columns)
        data.columns = ['open','high','low','close','vwap','volume','txn']
        # print(data)

        predict_proba_up = self.down_model.predict_proba(data)[:,1]
        # print(predict_proba_up)
        predict_proba_down = self.down_model.predict_proba(data)[:,1]
        # print(predict_proba_down)
        
        forecast = predict_proba_up > self.up_threshold and predict_proba_down < self.down_threshold
        # forecast = 1
        # print(forecast)
        
        tp = self.data.Close[-1] + 3 * self.tp
        sl = self.data.Close[-1] - self.sl
        if forecast and not self.position.is_long:
            print(self.data.df.iloc[-1])
            self.buy(size=1,tp=tp,sl=sl)

# %%
bt = Backtest(data, MLStrategy, cash=10_000_000, commission=.002)
stats = bt.run()
stats
# Out:
# Open      111700.0
# High      111850.0
# Low       111580.0
# Close     111670.0
# VWAP           0.0
# Volume       731.0
# Txn          466.0
# Name: 2022-08-19 10:01:00, dtype: float64
# Open      111670.0
# High      111670.0
# Low       111400.0
# Close     111520.0
# VWAP           0.0
# Volume       715.0
# Txn          413.0
# Name: 2022-08-19 10:02:00, dtype: float64
# Open      111450.0
# High      111670.0
# Low       111210.0
# Close     111250.0
# VWAP           0.0
# Volume      1014.0
# Txn          563.0
# Name: 2022-08-19 10:04:00, dtype: float64
# Open      111240.0
# High      111240.0
# Low       110930.0
# Close     111020.0
# VWAP           0.0
# Volume      1533.0
# Txn          957.0
# Name: 2022-08-19 10:05:00, dtype: float64
# Open      111020.0
# High      111100.0
# Low       110880.0
# Close     111060.0
# VWAP           0.0
# Volume       823.0
# Txn          509.0
# Name: 2022-08-19 10:06:00, dtype: float64
# Open      111000.0
# High      111010.0
# Low       110880.0
# Close     110980.0
# VWAP           0.0
# Volume       520.0
# Txn          291.0
# Name: 2022-08-19 10:10:00, dtype: float64
# Open      110960.0
# High      110970.0
# Low       110670.0
# Close     110840.0
# VWAP           0.0
# Volume      1097.0
# Txn          629.0
# Name: 2022-08-19 10:11:00, dtype: float64
# Open      110840.0
# High      110920.0
# Low       110760.0
# Close     110900.0
# VWAP           0.0
# Volume       685.0
# Txn          374.0
# Name: 2022-08-19 10:12:00, dtype: float64
# Open      110890.0
# High      111060.0
# Low       110810.0
# Close     111030.0
# VWAP           0.0
# Volume       476.0
# Txn          281.0
# Name: 2022-08-19 10:13:00, dtype: float64
# Open      111080.0
# High      111100.0
# Low       110920.0
# Close     110950.0
# VWAP           0.0
# Volume       362.0
# Txn          244.0
# Name: 2022-08-19 10:15:00, dtype: float64
# Open      111330.0
# High      111360.0
# Low       111210.0
# Close     111290.0
# VWAP           0.0
# Volume       404.0
# Txn          260.0
# Name: 2022-08-19 10:19:00, dtype: float64
# Open      111300.0
# High      111330.0
# Low       111100.0
# Close     111250.0
# VWAP           0.0
# Volume       367.0
# Txn          246.0
# Name: 2022-08-19 10:20:00, dtype: float64
# Open      111250.0
# High      111250.0
# Low       111190.0
# Close     111240.0
# VWAP           0.0
# Volume       193.0
# Txn          105.0
# Name: 2022-08-19 10:21:00, dtype: float64
# Open      111290.0
# High      111290.0
# Low       111100.0
# Close     111100.0
# VWAP           0.0
# Volume       269.0
# Txn          184.0
# Name: 2022-08-19 10:23:00, dtype: float64
# Open      111090.0
# High      111090.0
# Low       110930.0
# Close     110970.0
# VWAP           0.0
# Volume       410.0
# Txn          244.0
# Name: 2022-08-19 10:24:00, dtype: float64
# Open      110980.0
# High      111040.0
# Low       110770.0
# Close     110770.0
# VWAP           0.0
# Volume      1006.0
# Txn          496.0
# Name: 2022-08-19 10:25:00, dtype: float64
# Open      110770.0
# High      110870.0
# Low       110690.0
# Close     110820.0
# VWAP           0.0
# Volume       611.0
# Txn          378.0
# Name: 2022-08-19 10:26:00, dtype: float64
# Open      110780.0
# High      110920.0
# Low       110630.0
# Close     110840.0
# VWAP           0.0
# Volume       706.0
# Txn          389.0
# Name: 2022-08-19 10:29:00, dtype: float64
# Open      110860.0
# High      110860.0
# Low       110720.0
# Close     110780.0
# VWAP           0.0
# Volume       386.0
# Txn          215.0
# Name: 2022-08-19 10:30:00, dtype: float64
# Open      110780.0
# High      110800.0
# Low       110620.0
# Close     110710.0
# VWAP           0.0
# Volume       549.0
# Txn          239.0
# Name: 2022-08-19 10:31:00, dtype: float64
# Open      110700.0
# High      110720.0
# Low       110550.0
# Close     110560.0
# VWAP           0.0
# Volume       551.0
# Txn          293.0
# Name: 2022-08-19 10:32:00, dtype: float64
# Open      110570.0
# High      110600.0
# Low       110410.0
# Close     110600.0
# VWAP           0.0
# Volume      1112.0
# Txn          626.0
# Name: 2022-08-19 10:34:00, dtype: float64
# Open      110600.0
# High      110600.0
# Low       110510.0
# Close     110530.0
# VWAP           0.0
# Volume       222.0
# Txn          145.0
# Name: 2022-08-19 10:35:00, dtype: float64
# Open      110520.0
# High      110710.0
# Low       110470.0
# Close     110690.0
# VWAP           0.0
# Volume       803.0
# Txn          434.0
# Name: 2022-08-19 10:37:00, dtype: float64
# Open      110700.0
# High      110710.0
# Low       110590.0
# Close     110640.0
# VWAP           0.0
# Volume       175.0
# Txn          108.0
# Name: 2022-08-19 10:38:00, dtype: float64
# Open      110640.0
# High      110680.0
# Low       110560.0
# Close     110590.0
# VWAP           0.0
# Volume       540.0
# Txn          308.0
# Name: 2022-08-19 10:39:00, dtype: float64
# Open      110580.0
# High      110620.0
# Low       110430.0
# Close     110470.0
# VWAP           0.0
# Volume       580.0
# Txn          297.0
# Name: 2022-08-19 10:40:00, dtype: float64
# Open      110700.0
# High      110860.0
# Low       110640.0
# Close     110820.0
# VWAP           0.0
# Volume       503.0
# Txn          255.0
# Name: 2022-08-19 10:44:00, dtype: float64
# Open      110830.0
# High      110860.0
# Low       110710.0
# Close     110770.0
# VWAP           0.0
# Volume       360.0
# Txn          221.0
# Name: 2022-08-19 10:45:00, dtype: float64
# Open      110740.0
# High      110770.0
# Low       110640.0
# Close     110650.0
# VWAP           0.0
# Volume       285.0
# Txn          188.0
# Name: 2022-08-19 10:46:00, dtype: float64
# Open      110650.0
# High      110680.0
# Low       110520.0
# Close     110520.0
# VWAP           0.0
# Volume       518.0
# Txn          300.0
# Name: 2022-08-19 10:48:00, dtype: float64
# Open      110480.0
# High      110580.0
# Low       110460.0
# Close     110510.0
# VWAP           0.0
# Volume       250.0
# Txn          157.0
# Name: 2022-08-19 10:53:00, dtype: float64
# Open      110510.0
# High      110510.0
# Low       110290.0
# Close     110390.0
# VWAP           0.0
# Volume      1043.0
# Txn          615.0
# Name: 2022-08-19 10:54:00, dtype: float64
# Open      110380.0
# High      110430.0
# Low       110320.0
# Close     110330.0
# VWAP           0.0
# Volume       295.0
# Txn          191.0
# Name: 2022-08-19 10:55:00, dtype: float64
# Open      110360.0
# High      110360.0
# Low       110210.0
# Close     110310.0
# VWAP           0.0
# Volume       588.0
# Txn          305.0
# Name: 2022-08-19 10:58:00, dtype: float64
# Open      110300.0
# High      110330.0
# Low       110200.0
# Close     110200.0
# VWAP           0.0
# Volume       277.0
# Txn          175.0
# Name: 2022-08-19 10:59:00, dtype: float64
# Open      110210.0
# High      110210.0
# Low       110050.0
# Close     110090.0
# VWAP           0.0
# Volume      1082.0
# Txn          552.0
# Name: 2022-08-19 11:00:00, dtype: float64
# Open      110340.0
# High      110440.0
# Low       110270.0
# Close     110400.0
# VWAP           0.0
# Volume       562.0
# Txn          299.0
# Name: 2022-08-19 11:06:00, dtype: float64
# Open      110400.0
# High      110440.0
# Low       110320.0
# Close     110350.0
# VWAP           0.0
# Volume       417.0
# Txn          226.0
# Name: 2022-08-19 11:07:00, dtype: float64
# Open      110320.0
# High      110410.0
# Low       110210.0
# Close     110380.0
# VWAP           0.0
# Volume       548.0
# Txn          323.0
# Name: 2022-08-19 11:09:00, dtype: float64
# Open      110570.0
# High      110700.0
# Low       110550.0
# Close     110670.0
# VWAP           0.0
# Volume       557.0
# Txn          292.0
# Name: 2022-08-19 11:12:00, dtype: float64
# Open      110590.0
# High      110600.0
# Low       110420.0
# Close     110430.0
# VWAP           0.0
# Volume       593.0
# Txn          373.0
# Name: 2022-08-19 11:15:00, dtype: float64
# Open      110430.0
# High      110490.0
# Low       110340.0
# Close     110460.0
# VWAP           0.0
# Volume       577.0
# Txn          369.0
# Name: 2022-08-19 11:16:00, dtype: float64
# Open      110720.0
# High      110810.0
# Low       110630.0
# Close     110800.0
# VWAP           0.0
# Volume       622.0
# Txn          333.0
# Name: 2022-08-19 11:18:00, dtype: float64
# Open      111110.0
# High      111140.0
# Low       111040.0
# Close     111080.0
# VWAP           0.0
# Volume       284.0
# Txn          200.0
# Name: 2022-08-19 11:24:00, dtype: float64
# Open      111100.0
# High      111130.0
# Low       110940.0
# Close     110940.0
# VWAP           0.0
# Volume       538.0
# Txn          279.0
# Name: 2022-08-19 11:25:00, dtype: float64
# Open      111060.0
# High      111330.0
# Low       111060.0
# Close     111260.0
# VWAP           0.0
# Volume       759.0
# Txn          461.0
# Name: 2022-08-19 11:28:00, dtype: float64
# Open      111230.0
# High      111320.0
# Low       111160.0
# Close     111160.0
# VWAP           0.0
# Volume       348.0
# Txn          212.0
# Name: 2022-08-19 11:29:00, dtype: float64
# Open      111160.0
# High      111170.0
# Low       111020.0
# Close     111050.0
# VWAP           0.0
# Volume       397.0
# Txn          241.0
# Name: 2022-08-19 11:30:00, dtype: float64
# Open      110990.0
# High      111080.0
# Low       110920.0
# Close     110970.0
# VWAP           0.0
# Volume       251.0
# Txn          145.0
# Name: 2022-08-19 11:36:00, dtype: float64
# Open      110920.0
# High      110950.0
# Low       110810.0
# Close     110890.0
# VWAP           0.0
# Volume       247.0
# Txn          172.0
# Name: 2022-08-19 11:38:00, dtype: float64
# Open      110900.0
# High      110900.0
# Low       110760.0
# Close     110840.0
# VWAP           0.0
# Volume       203.0
# Txn          140.0
# Name: 2022-08-19 11:40:00, dtype: float64
# Open      110840.0
# High      110880.0
# Low       110730.0
# Close     110740.0
# VWAP           0.0
# Volume       157.0
# Txn           97.0
# Name: 2022-08-19 11:41:00, dtype: float64
# Open      110760.0
# High      110800.0
# Low       110670.0
# Close     110700.0
# VWAP           0.0
# Volume       239.0
# Txn          150.0
# Name: 2022-08-19 11:42:00, dtype: float64
# Open      110560.0
# High      110570.0
# Low       110200.0
# Close     110280.0
# VWAP           0.0
# Volume       981.0
# Txn          535.0
# Name: 2022-08-19 11:45:00, dtype: float64
# Open      110270.0
# High      110290.0
# Low       110110.0
# Close     110140.0
# VWAP           0.0
# Volume       572.0
# Txn          292.0
# Name: 2022-08-19 11:46:00, dtype: float64
# Open      110220.0
# High      110480.0
# Low       110140.0
# Close     110450.0
# VWAP           0.0
# Volume       422.0
# Txn          274.0
# Name: 2022-08-19 12:00:00, dtype: float64
# Open      110440.0
# High      110440.0
# Low       110390.0
# Close     110400.0
# VWAP           0.0
# Volume       124.0
# Txn           86.0
# Name: 2022-08-19 12:01:00, dtype: float64
# Open      110420.0
# High      110460.0
# Low       110320.0
# Close     110420.0
# VWAP           0.0
# Volume       577.0
# Txn          293.0
# Name: 2022-08-19 12:02:00, dtype: float64
# Open      110720.0
# High      110730.0
# Low       110650.0
# Close     110670.0
# VWAP           0.0
# Volume        92.0
# Txn           52.0
# Name: 2022-08-19 12:17:00, dtype: float64
# Open      110940.0
# High      110980.0
# Low       110940.0
# Close     110960.0
# VWAP           0.0
# Volume       118.0
# Txn           74.0
# Name: 2022-08-19 12:23:00, dtype: float64
# Open      110850.0
# High      110850.0
# Low       110670.0
# Close     110690.0
# VWAP           0.0
# Volume       325.0
# Txn          209.0
# Name: 2022-08-19 12:26:00, dtype: float64
# Open      110690.0
# High      110770.0
# Low       110630.0
# Close     110770.0
# VWAP           0.0
# Volume       235.0
# Txn          141.0
# Name: 2022-08-19 12:27:00, dtype: float64
# Open      110800.0
# High      110860.0
# Low       110690.0
# Close     110760.0
# VWAP           0.0
# Volume       266.0
# Txn          177.0
# Name: 2022-08-19 12:30:00, dtype: float64
# Open      110780.0
# High      110790.0
# Low       110750.0
# Close     110780.0
# VWAP           0.0
# Volume        59.0
# Txn           29.0
# Name: 2022-08-19 12:33:00, dtype: float64
# Open      110900.0
# High      111130.0
# Low       110880.0
# Close     111130.0
# VWAP           0.0
# Volume       909.0
# Txn          480.0
# Name: 2022-08-19 12:41:00, dtype: float64
# Open      111180.0
# High      111210.0
# Low       111060.0
# Close     111110.0
# VWAP           0.0
# Volume       288.0
# Txn          156.0
# Name: 2022-08-19 12:44:00, dtype: float64
# Open      111310.0
# High      111340.0
# Low       111210.0
# Close     111220.0
# VWAP           0.0
# Volume       168.0
# Txn          111.0
# Name: 2022-08-19 12:50:00, dtype: float64
# Open      111220.0
# High      111280.0
# Low       111130.0
# Close     111130.0
# VWAP           0.0
# Volume       258.0
# Txn          115.0
# Name: 2022-08-19 12:51:00, dtype: float64
# Open      111140.0
# High      111580.0
# Low       111120.0
# Close     111570.0
# VWAP           0.0
# Volume       791.0
# Txn          472.0
# Name: 2022-08-19 12:52:00, dtype: float64
# Open      111520.0
# High      111710.0
# Low       111480.0
# Close     111520.0
# VWAP           0.0
# Volume      1018.0
# Txn          612.0
# Name: 2022-08-19 12:53:00, dtype: float64
# Open      111520.0
# High      111630.0
# Low       111410.0
# Close     111450.0
# VWAP           0.0
# Volume       425.0
# Txn          267.0
# Name: 2022-08-19 12:54:00, dtype: float64
# Open      111420.0
# High      111650.0
# Low       111390.0
# Close     111640.0
# VWAP           0.0
# Volume       372.0
# Txn          220.0
# Name: 2022-08-19 13:01:00, dtype: float64
# Open      111640.0
# High      111640.0
# Low       111470.0
# Close     111470.0
# VWAP           0.0
# Volume       142.0
# Txn          113.0
# Name: 2022-08-19 13:02:00, dtype: float64
# Open      111700.0
# High      111870.0
# Low       111700.0
# Close     111810.0
# VWAP           0.0
# Volume       814.0
# Txn          490.0
# Name: 2022-08-19 13:26:00, dtype: float64
# Open      111820.0
# High      111970.0
# Low       111750.0
# Close     111780.0
# VWAP           0.0
# Volume       791.0
# Txn          468.0
# Name: 2022-08-19 13:27:00, dtype: float64
# Open      111830.0
# High      111830.0
# Low       111640.0
# Close     111670.0
# VWAP           0.0
# Volume       336.0
# Txn          213.0
# Name: 2022-08-19 13:32:00, dtype: float64
# Open      111890.0
# High      111990.0
# Low       111770.0
# Close     111770.0
# VWAP           0.0
# Volume       253.0
# Txn          166.0
# Name: 2022-08-19 13:36:00, dtype: float64
# Open      111750.0
# High      111800.0
# Low       111730.0
# Close     111730.0
# VWAP           0.0
# Volume        52.0
# Txn           43.0
# Name: 2022-08-19 13:39:00, dtype: float64
# Open      111930.0
# High      112140.0
# Low       111910.0
# Close     112100.0
# VWAP           0.0
# Volume      1205.0
# Txn          577.0
# Name: 2022-08-19 13:43:00, dtype: float64
# Open      111840.0
# High      111840.0
# Low       111750.0
# Close     111820.0
# VWAP           0.0
# Volume       196.0
# Txn          126.0
# Name: 2022-08-19 13:46:00, dtype: float64
# Open      111800.0
# High      111800.0
# Low       111700.0
# Close     111730.0
# VWAP           0.0
# Volume       159.0
# Txn          116.0
# Name: 2022-08-19 13:49:00, dtype: float64
# Open      111730.0
# High      111730.0
# Low       111650.0
# Close     111690.0
# VWAP           0.0
# Volume       200.0
# Txn          108.0
# Name: 2022-08-19 13:55:00, dtype: float64
# Open      111810.0
# High      112000.0
# Low       111810.0
# Close     111930.0
# VWAP           0.0
# Volume       353.0
# Txn          190.0
# Name: 2022-08-19 14:08:00, dtype: float64
# Open      112150.0
# High      112240.0
# Low       112070.0
# Close     112070.0
# VWAP           0.0
# Volume       700.0
# Txn          317.0
# Name: 2022-08-19 14:24:00, dtype: float64
# Open      112100.0
# High      112190.0
# Low       111980.0
# Close     111980.0
# VWAP           0.0
# Volume       481.0
# Txn          257.0
# Name: 2022-08-19 14:41:00, dtype: float64
# Open      111980.0
# High      111990.0
# Low       111890.0
# Close     111900.0
# VWAP           0.0
# Volume       273.0
# Txn          175.0
# Name: 2022-08-19 14:42:00, dtype: float64
# Open      111750.0
# High      111780.0
# Low       111670.0
# Close     111730.0
# VWAP           0.0
# Volume       331.0
# Txn          201.0
# Name: 2022-08-19 14:44:00, dtype: float64
# Open      111720.0
# High      111720.0
# Low       111510.0
# Close     111580.0
# VWAP           0.0
# Volume      1110.0
# Txn          534.0
# Name: 2022-08-19 14:45:00, dtype: float64
# Open      111850.0
# High      111910.0
# Low       111830.0
# Close     111840.0
# VWAP           0.0
# Volume       118.0
# Txn           74.0
# Name: 2022-08-19 14:59:00, dtype: float64
# Open      111840.0
# High      111850.0
# Low       111710.0
# Close     111730.0
# VWAP           0.0
# Volume       151.0
# Txn          106.0
# Name: 2022-08-19 15:01:00, dtype: float64
# Open      112020.0
# High      112050.0
# Low       111980.0
# Close     112010.0
# VWAP           0.0
# Volume       195.0
# Txn          118.0
# Name: 2022-08-19 15:08:00, dtype: float64
# Open      112020.0
# High      112030.0
# Low       111930.0
# Close     111970.0
# VWAP           0.0
# Volume       398.0
# Txn          190.0
# Name: 2022-08-19 15:09:00, dtype: float64
# Open      112060.0
# High      112080.0
# Low       111880.0
# Close     111880.0
# VWAP           0.0
# Volume       158.0
# Txn          113.0
# Name: 2022-08-19 15:13:00, dtype: float64
# Open      111900.0
# High      112000.0
# Low       111820.0
# Close     111990.0
# VWAP           0.0
# Volume       289.0
# Txn          161.0
# Name: 2022-08-19 15:15:00, dtype: float64
# Open      111970.0
# High      111970.0
# Low       111840.0
# Close     111840.0
# VWAP           0.0
# Volume        53.0
# Txn           42.0
# Name: 2022-08-19 15:18:00, dtype: float64
# Open      111850.0
# High      111860.0
# Low       111700.0
# Close     111700.0
# VWAP           0.0
# Volume       277.0
# Txn          187.0
# Name: 2022-08-19 15:19:00, dtype: float64
# Open      111910.0
# High      112040.0
# Low       111910.0
# Close     111970.0
# VWAP           0.0
# Volume       130.0
# Txn           93.0
# Name: 2022-08-19 15:26:00, dtype: float64
# Open      112200.0
# High      112290.0
# Low       112170.0
# Close     112240.0
# VWAP           0.0
# Volume       219.0
# Txn          147.0
# Name: 2022-08-19 15:34:00, dtype: float64
# Open      112230.0
# High      112280.0
# Low       112160.0
# Close     112240.0
# VWAP           0.0
# Volume       186.0
# Txn           90.0
# Name: 2022-08-19 15:35:00, dtype: float64
# Open      112250.0
# High      112270.0
# Low       112170.0
# Close     112180.0
# VWAP           0.0
# Volume       149.0
# Txn          100.0
# Name: 2022-08-19 15:36:00, dtype: float64
# Open      112170.0
# High      112190.0
# Low       112100.0
# Close     112100.0
# VWAP           0.0
# Volume       158.0
# Txn           91.0
# Name: 2022-08-19 15:45:00, dtype: float64
# Open      112080.0
# High      112100.0
# Low       112000.0
# Close     112070.0
# VWAP           0.0
# Volume       331.0
# Txn          168.0
# Name: 2022-08-19 15:47:00, dtype: float64
# Open      112110.0
# High      112120.0
# Low       111940.0
# Close     111950.0
# VWAP           0.0
# Volume       205.0
# Txn          114.0
# Name: 2022-08-19 15:50:00, dtype: float64
# Open      112000.0
# High      112000.0
# Low       111820.0
# Close     111830.0
# VWAP           0.0
# Volume       251.0
# Txn          163.0
# Name: 2022-08-19 15:52:00, dtype: float64
# Open      112120.0
# High      112170.0
# Low       112110.0
# Close     112140.0
# VWAP           0.0
# Volume        94.0
# Txn           60.0
# Name: 2022-08-19 16:07:00, dtype: float64
# Open      112130.0
# High      112130.0
# Low       112070.0
# Close     112090.0
# VWAP           0.0
# Volume        70.0
# Txn           46.0
# Name: 2022-08-19 16:08:00, dtype: float64
# Open      112090.0
# High      112100.0
# Low       112030.0
# Close     112100.0
# VWAP           0.0
# Volume        48.0
# Txn           31.0
# Name: 2022-08-19 16:09:00, dtype: float64
# Open      112090.0
# High      112120.0
# Low       112030.0
# Close     112080.0
# VWAP           0.0
# Volume       447.0
# Txn          246.0
# Name: 2022-08-19 16:19:00, dtype: float64
# Open      112360.0
# High      112390.0
# Low       112300.0
# Close     112300.0
# VWAP           0.0
# Volume       255.0
# Txn          127.0
# Name: 2022-08-19 16:25:00, dtype: float64
# Open      112300.0
# High      112380.0
# Low       112230.0
# Close     112340.0
# VWAP           0.0
# Volume       146.0
# Txn           94.0
# Name: 2022-08-19 16:26:00, dtype: float64
# Open      112360.0
# High      112390.0
# Low       112220.0
# Close     112230.0
# VWAP           0.0
# Volume       101.0
# Txn           76.0
# Name: 2022-08-19 16:27:00, dtype: float64
# Open      112240.0
# High      112280.0
# Low       112100.0
# Close     112180.0
# VWAP           0.0
# Volume       213.0
# Txn          170.0
# Name: 2022-08-19 16:28:00, dtype: float64
# Open      112140.0
# High      112170.0
# Low       112050.0
# Close     112090.0
# VWAP           0.0
# Volume       209.0
# Txn          119.0
# Name: 2022-08-19 16:33:00, dtype: float64
# Open      112090.0
# High      112090.0
# Low       111600.0
# Close     111660.0
# VWAP           0.0
# Volume      1214.0
# Txn          760.0
# Name: 2022-08-19 16:34:00, dtype: float64
# Open      111740.0
# High      111880.0
# Low       111710.0
# Close     111810.0
# VWAP           0.0
# Volume       272.0
# Txn          182.0
# Name: 2022-08-19 16:36:00, dtype: float64
# Open      111790.0
# High      111820.0
# Low       111670.0
# Close     111690.0
# VWAP           0.0
# Volume       219.0
# Txn          117.0
# Name: 2022-08-19 16:37:00, dtype: float64
# Open      111750.0
# High      111800.0
# Low       111610.0
# Close     111610.0
# VWAP           0.0
# Volume       228.0
# Txn          140.0
# Name: 2022-08-19 16:50:00, dtype: float64
# Open      111690.0
# High      111720.0
# Low       111380.0
# Close     111450.0
# VWAP           0.0
# Volume       942.0
# Txn          468.0
# Name: 2022-08-19 16:54:00, dtype: float64
# Open      111430.0
# High      111500.0
# Low       111260.0
# Close     111320.0
# VWAP           0.0
# Volume       492.0
# Txn          277.0
# Name: 2022-08-19 16:55:00, dtype: float64
# Open      111330.0
# High      111360.0
# Low       111240.0
# Close     111340.0
# VWAP           0.0
# Volume       354.0
# Txn          228.0
# Name: 2022-08-19 16:56:00, dtype: float64
# Open      111480.0
# High      111480.0
# Low       111280.0
# Close     111390.0
# VWAP           0.0
# Volume       227.0
# Txn          154.0
# Name: 2022-08-19 17:00:00, dtype: float64
# Open      111480.0
# High      111550.0
# Low       111270.0
# Close     111520.0
# VWAP           0.0
# Volume       298.0
# Txn          194.0
# Name: 2022-08-19 17:03:00, dtype: float64
# Open      111760.0
# High      111840.0
# Low       111670.0
# Close     111800.0
# VWAP           0.0
# Volume       393.0
# Txn          233.0
# Name: 2022-08-19 17:06:00, dtype: float64
# Open      111800.0
# High      111830.0
# Low       111660.0
# Close     111700.0
# VWAP           0.0
# Volume       111.0
# Txn           81.0
# Name: 2022-08-19 17:07:00, dtype: float64
# Open      111720.0
# High      111720.0
# Low       111640.0
# Close     111640.0
# VWAP           0.0
# Volume        91.0
# Txn           64.0
# Name: 2022-08-19 17:13:00, dtype: float64
# Open      111620.0
# High      111730.0
# Low       111550.0
# Close     111700.0
# VWAP           0.0
# Volume       178.0
# Txn          125.0
# Name: 2022-08-19 17:17:00, dtype: float64
# Open      111690.0
# High      111700.0
# Low       111430.0
# Close     111430.0
# VWAP           0.0
# Volume       155.0
# Txn          110.0
# Name: 2022-08-19 17:18:00, dtype: float64
# Open      111510.0
# High      111550.0
# Low       111360.0
# Close     111360.0
# VWAP           0.0
# Volume       781.0
# Txn          484.0
# Name: 2022-08-19 17:24:00, dtype: float64
# Open      111480.0
# High      111710.0
# Low       111480.0
# Close     111700.0
# VWAP           0.0
# Volume       391.0
# Txn          220.0
# Name: 2022-08-19 17:31:00, dtype: float64
# Open      111710.0
# High      111790.0
# Low       111550.0
# Close     111630.0
# VWAP           0.0
# Volume       857.0
# Txn          489.0
# Name: 2022-08-19 17:32:00, dtype: float64
# Open      111770.0
# High      111850.0
# Low       111730.0
# Close     111830.0
# VWAP           0.0
# Volume       534.0
# Txn          305.0
# Name: 2022-08-19 17:34:00, dtype: float64
# Open      111820.0
# High      111830.0
# Low       111730.0
# Close     111740.0
# VWAP           0.0
# Volume        63.0
# Txn           49.0
# Name: 2022-08-19 17:35:00, dtype: float64
# Open      111750.0
# High      111770.0
# Low       111680.0
# Close     111720.0
# VWAP           0.0
# Volume       106.0
# Txn           56.0
# Name: 2022-08-19 17:36:00, dtype: float64
# Open      111980.0
# High      112060.0
# Low       111970.0
# Close     111970.0
# VWAP           0.0
# Volume       277.0
# Txn          138.0
# Name: 2022-08-19 17:42:00, dtype: float64
# Open      111970.0
# High      111980.0
# Low       111900.0
# Close     111910.0
# VWAP           0.0
# Volume        92.0
# Txn           57.0
# Name: 2022-08-19 17:43:00, dtype: float64
# Open      111940.0
# High      111970.0
# Low       111830.0
# Close     111840.0
# VWAP           0.0
# Volume       337.0
# Txn          182.0
# Name: 2022-08-19 17:44:00, dtype: float64
# Open      111850.0
# High      111890.0
# Low       111740.0
# Close     111800.0
# VWAP           0.0
# Volume       184.0
# Txn          102.0
# Name: 2022-08-19 17:45:00, dtype: float64
# Open      111830.0
# High      111830.0
# Low       111720.0
# Close     111760.0
# VWAP           0.0
# Volume        43.0
# Txn           31.0
# Name: 2022-08-19 17:47:00, dtype: float64
# Open      111780.0
# High      111810.0
# Low       111700.0
# Close     111700.0
# VWAP           0.0
# Volume        99.0
# Txn           70.0
# Name: 2022-08-19 17:48:00, dtype: float64
# Open      111910.0
# High      112090.0
# Low       111880.0
# Close     112040.0
# VWAP           0.0
# Volume       240.0
# Txn          180.0
# Name: 2022-08-19 17:51:00, dtype: float64
# Open      112010.0
# High      112050.0
# Low       111950.0
# Close     111950.0
# VWAP           0.0
# Volume       102.0
# Txn           71.0
# Name: 2022-08-19 17:59:00, dtype: float64
# Open      111950.0
# High      111950.0
# Low       111790.0
# Close     111840.0
# VWAP           0.0
# Volume       187.0
# Txn          114.0
# Name: 2022-08-19 18:02:00, dtype: float64
# Open      111830.0
# High      111860.0
# Low       111740.0
# Close     111800.0
# VWAP           0.0
# Volume       157.0
# Txn           46.0
# Name: 2022-08-19 18:06:00, dtype: float64
# Open      112040.0
# High      112150.0
# Low       112000.0
# Close     112130.0
# VWAP           0.0
# Volume       166.0
# Txn          107.0
# Name: 2022-08-19 18:24:00, dtype: float64
# Open      112360.0
# High      112440.0
# Low       112300.0
# Close     112310.0
# VWAP           0.0
# Volume       383.0
# Txn          233.0
# Name: 2022-08-19 18:40:00, dtype: float64
# Open      112270.0
# High      112290.0
# Low       112140.0
# Close     112270.0
# VWAP           0.0
# Volume       122.0
# Txn          101.0
# Name: 2022-08-19 18:42:00, dtype: float64
# Open      112240.0
# High      112270.0
# Low       112210.0
# Close     112230.0
# VWAP           0.0
# Volume        32.0
# Txn           29.0
# Name: 2022-08-19 18:43:00, dtype: float64
# Open      112240.0
# High      112240.0
# Low       112150.0
# Close     112200.0
# VWAP           0.0
# Volume       124.0
# Txn           85.0
# Name: 2022-08-19 18:44:00, dtype: float64
# Open      112160.0
# High      112190.0
# Low       112120.0
# Close     112140.0
# VWAP           0.0
# Volume        45.0
# Txn           36.0
# Name: 2022-08-19 18:45:00, dtype: float64
# Open      112130.0
# High      112140.0
# Low       112080.0
# Close     112100.0
# VWAP           0.0
# Volume        61.0
# Txn           34.0
# Name: 2022-08-19 18:47:00, dtype: float64
# Open      112040.0
# High      112050.0
# Low       112010.0
# Close     112050.0
# VWAP           0.0
# Volume        29.0
# Txn           18.0
# Name: 2022-08-19 19:13:00, dtype: float64
# Open      112040.0
# High      112040.0
# Low       111910.0
# Close     111930.0
# VWAP           0.0
# Volume       105.0
# Txn           61.0
# Name: 2022-08-19 19:15:00, dtype: float64
# Open      112170.0
# High      112300.0
# Low       112170.0
# Close     112300.0
# VWAP           0.0
# Volume       143.0
# Txn           74.0
# Name: 2022-08-19 19:44:00, dtype: float64
# Open      112280.0
# High      112320.0
# Low       112220.0
# Close     112310.0
# VWAP           0.0
# Volume        21.0
# Txn           19.0
# Name: 2022-08-19 19:45:00, dtype: float64
# Open      112310.0
# High      112330.0
# Low       112200.0
# Close     112200.0
# VWAP           0.0
# Volume        57.0
# Txn           32.0
# Name: 2022-08-19 19:46:00, dtype: float64
# Open      112160.0
# High      112200.0
# Low       112130.0
# Close     112130.0
# VWAP           0.0
# Volume        35.0
# Txn           26.0
# Name: 2022-08-19 21:00:00, dtype: float64
# Open      112120.0
# High      112120.0
# Low       112060.0
# Close     112060.0
# VWAP           0.0
# Volume        39.0
# Txn           23.0
# Name: 2022-08-19 21:03:00, dtype: float64
# Open      112100.0
# High      112100.0
# Low       112000.0
# Close     112020.0
# VWAP           0.0
# Volume        82.0
# Txn           55.0
# Name: 2022-08-19 22:13:00, dtype: float64
# Open      112050.0
# High      112050.0
# Low       111960.0
# Close     111960.0
# VWAP           0.0
# Volume        64.0
# Txn           33.0
# Name: 2022-08-19 22:36:00, dtype: float64
# Open      111980.0
# High      112310.0
# Low       111970.0
# Close     112310.0
# VWAP           0.0
# Volume       374.0
# Txn          183.0
# Name: 2022-08-19 23:19:00, dtype: float64
# Open      112250.0
# High      112390.0
# Low       112240.0
# Close     112370.0
# VWAP           0.0
# Volume       223.0
# Txn          120.0
# Name: 2022-08-19 23:20:00, dtype: float64
# Open      112400.0
# High      112430.0
# Low       112290.0
# Close     112390.0
# VWAP           0.0
# Volume        28.0
# Txn           26.0
# Name: 2022-08-19 23:23:00, dtype: float64
# Open      113470.0
# High      113700.0
# Low       113320.0
# Close     113570.0
# VWAP           0.0
# Volume       903.0
# Txn          589.0
# Name: 2022-08-23 10:00:00, dtype: float64
# Open      113560.0
# High      113710.0
# Low       113350.0
# Close     113700.0
# VWAP           0.0
# Volume       768.0
# Txn          456.0
# Name: 2022-08-23 10:01:00, dtype: float64
# Open      113680.0
# High      113890.0
# Low       113540.0
# Close     113720.0
# VWAP           0.0
# Volume       919.0
# Txn          522.0
# Name: 2022-08-23 10:02:00, dtype: float64
# Open      113700.0
# High      113710.0
# Low       113600.0
# Close     113670.0
# VWAP           0.0
# Volume       220.0
# Txn          164.0
# Name: 2022-08-23 10:03:00, dtype: float64
# Open      113670.0
# High      113690.0
# Low       113500.0
# Close     113690.0
# VWAP           0.0
# Volume       498.0
# Txn          273.0
# Name: 2022-08-23 10:04:00, dtype: float64
# Open      113700.0
# High      113760.0
# Low       113500.0
# Close     113600.0
# VWAP           0.0
# Volume       831.0
# Txn          441.0
# Name: 2022-08-23 10:05:00, dtype: float64
# Open      113630.0
# High      113750.0
# Low       113510.0
# Close     113550.0
# VWAP           0.0
# Volume       393.0
# Txn          251.0
# Name: 2022-08-23 10:07:00, dtype: float64
# Open      113570.0
# High      113640.0
# Low       113180.0
# Close     113390.0
# VWAP           0.0
# Volume      1179.0
# Txn          692.0
# Name: 2022-08-23 10:08:00, dtype: float64
# Open      113400.0
# High      113420.0
# Low       113220.0
# Close     113280.0
# VWAP           0.0
# Volume       899.0
# Txn          494.0
# Name: 2022-08-23 10:09:00, dtype: float64
# Open      113260.0
# High      113260.0
# Low       113030.0
# Close     113100.0
# VWAP           0.0
# Volume      1040.0
# Txn          496.0
# Name: 2022-08-23 10:10:00, dtype: float64
# Open      113080.0
# High      113220.0
# Low       112950.0
# Close     113020.0
# VWAP           0.0
# Volume      1054.0
# Txn          569.0
# Name: 2022-08-23 10:11:00, dtype: float64
# Open      113030.0
# High      113050.0
# Low       112790.0
# Close     112880.0
# VWAP           0.0
# Volume      1135.0
# Txn          651.0
# Name: 2022-08-23 10:12:00, dtype: float64
# Open      112870.0
# High      112880.0
# Low       112740.0
# Close     112800.0
# VWAP           0.0
# Volume       693.0
# Txn          310.0
# Name: 2022-08-23 10:14:00, dtype: float64
# Open      112810.0
# High      112810.0
# Low       112680.0
# Close     112800.0
# VWAP           0.0
# Volume       581.0
# Txn          297.0
# Name: 2022-08-23 10:15:00, dtype: float64
# Open      112760.0
# High      112800.0
# Low       112670.0
# Close     112760.0
# VWAP           0.0
# Volume       474.0
# Txn          272.0
# Name: 2022-08-23 10:17:00, dtype: float64
# Open      113020.0
# High      113250.0
# Low       113000.0
# Close     113200.0
# VWAP           0.0
# Volume       746.0
# Txn          413.0
# Name: 2022-08-23 10:25:00, dtype: float64
# Open      113180.0
# High      113240.0
# Low       113080.0
# Close     113220.0
# VWAP           0.0
# Volume       201.0
# Txn          147.0
# Name: 2022-08-23 10:26:00, dtype: float64
# Open      113230.0
# High      113300.0
# Low       113090.0
# Close     113130.0
# VWAP           0.0
# Volume       813.0
# Txn          494.0
# Name: 2022-08-23 10:27:00, dtype: float64
# Open      113190.0
# High      113530.0
# Low       113180.0
# Close     113500.0
# VWAP           0.0
# Volume       702.0
# Txn          412.0
# Name: 2022-08-23 10:31:00, dtype: float64
# Open      113490.0
# High      113770.0
# Low       113430.0
# Close     113760.0
# VWAP           0.0
# Volume      1058.0
# Txn          649.0
# Name: 2022-08-23 10:32:00, dtype: float64
# Open      113750.0
# High      113960.0
# Low       113610.0
# Close     113880.0
# VWAP           0.0
# Volume      1213.0
# Txn          673.0
# Name: 2022-08-23 10:33:00, dtype: float64
# Open      113960.0
# High      114200.0
# Low       113950.0
# Close     114050.0
# VWAP           0.0
# Volume      1293.0
# Txn          699.0
# Name: 2022-08-23 10:36:00, dtype: float64
# Open      114050.0
# High      114150.0
# Low       113910.0
# Close     113920.0
# VWAP           0.0
# Volume       657.0
# Txn          355.0
# Name: 2022-08-23 10:37:00, dtype: float64
# Open      114120.0
# High      114300.0
# Low       113980.0
# Close     114290.0
# VWAP           0.0
# Volume       538.0
# Txn          301.0
# Name: 2022-08-23 10:41:00, dtype: float64
# Open      114280.0
# High      114280.0
# Low       113920.0
# Close     113930.0
# VWAP           0.0
# Volume       485.0
# Txn          250.0
# Name: 2022-08-23 10:42:00, dtype: float64
# Open      113930.0
# High      114030.0
# Low       113860.0
# Close     113920.0
# VWAP           0.0
# Volume       719.0
# Txn          444.0
# Name: 2022-08-23 10:43:00, dtype: float64
# Open      114090.0
# High      114130.0
# Low       113800.0
# Close     113880.0
# VWAP           0.0
# Volume       535.0
# Txn          309.0
# Name: 2022-08-23 10:45:00, dtype: float64
# Open      113880.0
# High      113890.0
# Low       113770.0
# Close     113820.0
# VWAP           0.0
# Volume       198.0
# Txn          130.0
# Name: 2022-08-23 10:46:00, dtype: float64
# Open      113820.0
# High      113820.0
# Low       113720.0
# Close     113720.0
# VWAP           0.0
# Volume       137.0
# Txn          104.0
# Name: 2022-08-23 10:47:00, dtype: float64
# Open      113960.0
# High      114070.0
# Low       113900.0
# Close     113900.0
# VWAP           0.0
# Volume       333.0
# Txn          215.0
# Name: 2022-08-23 10:54:00, dtype: float64
# Open      113920.0
# High      114280.0
# Low       113910.0
# Close     114280.0
# VWAP           0.0
# Volume       396.0
# Txn          256.0
# Name: 2022-08-23 10:55:00, dtype: float64
# Open      114280.0
# High      114310.0
# Low       114150.0
# Close     114240.0
# VWAP           0.0
# Volume       544.0
# Txn          329.0
# Name: 2022-08-23 10:56:00, dtype: float64
# Open      114220.0
# High      114570.0
# Low       114220.0
# Close     114500.0
# VWAP           0.0
# Volume      1318.0
# Txn          708.0
# Name: 2022-08-23 10:57:00, dtype: float64
# Open      114520.0
# High      114560.0
# Low       114360.0
# Close     114460.0
# VWAP           0.0
# Volume       577.0
# Txn          294.0
# Name: 2022-08-23 10:58:00, dtype: float64
# Open      114470.0
# High      114570.0
# Low       114400.0
# Close     114490.0
# VWAP           0.0
# Volume       602.0
# Txn          305.0
# Name: 2022-08-23 10:59:00, dtype: float64
# Open      114550.0
# High      114570.0
# Low       114240.0
# Close     114380.0
# VWAP           0.0
# Volume       751.0
# Txn          439.0
# Name: 2022-08-23 11:03:00, dtype: float64
# Open      114380.0
# High      114440.0
# Low       114160.0
# Close     114170.0
# VWAP           0.0
# Volume       507.0
# Txn          289.0
# Name: 2022-08-23 11:04:00, dtype: float64
# Open      114400.0
# High      114490.0
# Low       114360.0
# Close     114360.0
# VWAP           0.0
# Volume       231.0
# Txn          129.0
# Name: 2022-08-23 11:07:00, dtype: float64
# Open      114500.0
# High      114500.0
# Low       114300.0
# Close     114350.0
# VWAP           0.0
# Volume       227.0
# Txn          139.0
# Name: 2022-08-23 11:09:00, dtype: float64
# Open      114440.0
# High      114470.0
# Low       114200.0
# Close     114210.0
# VWAP           0.0
# Volume       173.0
# Txn          128.0
# Name: 2022-08-23 11:11:00, dtype: float64
# Open      114210.0
# High      114260.0
# Low       114120.0
# Close     114180.0
# VWAP           0.0
# Volume       284.0
# Txn          199.0
# Name: 2022-08-23 11:12:00, dtype: float64
# Open      114170.0
# High      114190.0
# Low       114120.0
# Close     114130.0
# VWAP           0.0
# Volume        85.0
# Txn           64.0
# Name: 2022-08-23 11:13:00, dtype: float64
# Open      114140.0
# High      114240.0
# Low       113990.0
# Close     114080.0
# VWAP           0.0
# Volume       497.0
# Txn          292.0
# Name: 2022-08-23 11:14:00, dtype: float64
# Open      114290.0
# High      114440.0
# Low       114290.0
# Close     114300.0
# VWAP           0.0
# Volume       297.0
# Txn          163.0
# Name: 2022-08-23 11:16:00, dtype: float64
# Open      114300.0
# High      114360.0
# Low       114050.0
# Close     114060.0
# VWAP           0.0
# Volume       284.0
# Txn          198.0
# Name: 2022-08-23 11:17:00, dtype: float64
# Open      114060.0
# High      114250.0
# Low       113990.0
# Close     114050.0
# VWAP           0.0
# Volume       690.0
# Txn          395.0
# Name: 2022-08-23 11:18:00, dtype: float64
# Open      114040.0
# High      114120.0
# Low       113940.0
# Close     113950.0
# VWAP           0.0
# Volume       497.0
# Txn          276.0
# Name: 2022-08-23 11:19:00, dtype: float64
# Open      113930.0
# High      113950.0
# Low       113820.0
# Close     113880.0
# VWAP           0.0
# Volume       150.0
# Txn          133.0
# Name: 2022-08-23 11:21:00, dtype: float64
# Open      114090.0
# High      114330.0
# Low       114090.0
# Close     114280.0
# VWAP           0.0
# Volume       277.0
# Txn          184.0
# Name: 2022-08-23 11:24:00, dtype: float64
# Open      114270.0
# High      114340.0
# Low       114200.0
# Close     114260.0
# VWAP           0.0
# Volume       163.0
# Txn          104.0
# Name: 2022-08-23 11:25:00, dtype: float64
# Open      114260.0
# High      114390.0
# Low       114170.0
# Close     114170.0
# VWAP           0.0
# Volume       419.0
# Txn          283.0
# Name: 2022-08-23 11:34:00, dtype: float64
# Open      114150.0
# High      114180.0
# Low       113930.0
# Close     113990.0
# VWAP           0.0
# Volume       335.0
# Txn          244.0
# Name: 2022-08-23 11:36:00, dtype: float64
# Open      114290.0
# High      114410.0
# Low       114220.0
# Close     114250.0
# VWAP           0.0
# Volume       257.0
# Txn          167.0
# Name: 2022-08-23 11:40:00, dtype: float64
# Open      114230.0
# High      114280.0
# Low       114100.0
# Close     114180.0
# VWAP           0.0
# Volume       120.0
# Txn          108.0
# Name: 2022-08-23 11:41:00, dtype: float64
# Open      114170.0
# High      114280.0
# Low       114120.0
# Close     114130.0
# VWAP           0.0
# Volume       210.0
# Txn          143.0
# Name: 2022-08-23 11:43:00, dtype: float64
# Open      114200.0
# High      114250.0
# Low       114070.0
# Close     114070.0
# VWAP           0.0
# Volume       217.0
# Txn          113.0
# Name: 2022-08-23 11:49:00, dtype: float64
# Open      114080.0
# High      114120.0
# Low       113960.0
# Close     114120.0
# VWAP           0.0
# Volume       569.0
# Txn          312.0
# Name: 2022-08-23 11:50:00, dtype: float64
# Open      114140.0
# High      114170.0
# Low       113940.0
# Close     113950.0
# VWAP           0.0
# Volume       228.0
# Txn          141.0
# Name: 2022-08-23 11:53:00, dtype: float64
# Open      114030.0
# High      114040.0
# Low       113880.0
# Close     113880.0
# VWAP           0.0
# Volume       103.0
# Txn           72.0
# Name: 2022-08-23 11:55:00, dtype: float64
# Open      113860.0
# High      113920.0
# Low       113770.0
# Close     113890.0
# VWAP           0.0
# Volume       372.0
# Txn          267.0
# Name: 2022-08-23 11:58:00, dtype: float64
# Open      114050.0
# High      114120.0
# Low       113810.0
# Close     113940.0
# VWAP           0.0
# Volume       620.0
# Txn          400.0
# Name: 2022-08-23 12:01:00, dtype: float64
# Open      113940.0
# High      113960.0
# Low       113860.0
# Close     113900.0
# VWAP           0.0
# Volume        79.0
# Txn           60.0
# Name: 2022-08-23 12:02:00, dtype: float64
# Open      113930.0
# High      114040.0
# Low       113930.0
# Close     114010.0
# VWAP           0.0
# Volume       129.0
# Txn          108.0
# Name: 2022-08-23 12:16:00, dtype: float64
# Open      114280.0
# High      114360.0
# Low       114220.0
# Close     114310.0
# VWAP           0.0
# Volume       309.0
# Txn          183.0
# Name: 2022-08-23 12:22:00, dtype: float64
# Open      114320.0
# High      114320.0
# Low       114230.0
# Close     114250.0
# VWAP           0.0
# Volume       149.0
# Txn           72.0
# Name: 2022-08-23 12:23:00, dtype: float64
# Open      114280.0
# High      114300.0
# Low       114180.0
# Close     114210.0
# VWAP           0.0
# Volume       207.0
# Txn          116.0
# Name: 2022-08-23 12:28:00, dtype: float64
# Open      114200.0
# High      114260.0
# Low       114110.0
# Close     114170.0
# VWAP           0.0
# Volume       229.0
# Txn          144.0
# Name: 2022-08-23 12:30:00, dtype: float64
# Open      114160.0
# High      114240.0
# Low       114110.0
# Close     114110.0
# VWAP           0.0
# Volume       298.0
# Txn          143.0
# Name: 2022-08-23 12:31:00, dtype: float64
# Open      114130.0
# High      114160.0
# Low       114050.0
# Close     114110.0
# VWAP           0.0
# Volume       242.0
# Txn          141.0
# Name: 2022-08-23 12:32:00, dtype: float64
# Open      114110.0
# High      114120.0
# Low       113980.0
# Close     114010.0
# VWAP           0.0
# Volume       187.0
# Txn          109.0
# Name: 2022-08-23 12:34:00, dtype: float64
# Open      114010.0
# High      114020.0
# Low       113900.0
# Close     113980.0
# VWAP           0.0
# Volume       260.0
# Txn          174.0
# Name: 2022-08-23 12:35:00, dtype: float64
# Open      113970.0
# High      113990.0
# Low       113860.0
# Close     113890.0
# VWAP           0.0
# Volume       151.0
# Txn           97.0
# Name: 2022-08-23 12:36:00, dtype: float64
# Open      113940.0
# High      113970.0
# Low       113640.0
# Close     113700.0
# VWAP           0.0
# Volume      1133.0
# Txn          603.0
# Name: 2022-08-23 12:45:00, dtype: float64
# Open      113700.0
# High      113730.0
# Low       113630.0
# Close     113680.0
# VWAP           0.0
# Volume       310.0
# Txn          198.0
# Name: 2022-08-23 12:46:00, dtype: float64
# Open      113890.0
# High      114180.0
# Low       113890.0
# Close     114140.0
# VWAP           0.0
# Volume       561.0
# Txn          290.0
# Name: 2022-08-23 12:56:00, dtype: float64
# Open      114130.0
# High      114160.0
# Low       114000.0
# Close     114100.0
# VWAP           0.0
# Volume       179.0
# Txn          123.0
# Name: 2022-08-23 12:57:00, dtype: float64
# Open      114110.0
# High      114130.0
# Low       114040.0
# Close     114080.0
# VWAP           0.0
# Volume        88.0
# Txn           61.0
# Name: 2022-08-23 12:58:00, dtype: float64
# Open      114210.0
# High      114440.0
# Low       114210.0
# Close     114410.0
# VWAP           0.0
# Volume       539.0
# Txn          313.0
# Name: 2022-08-23 13:08:00, dtype: float64
# Open      114400.0
# High      114460.0
# Low       114320.0
# Close     114410.0
# VWAP           0.0
# Volume       351.0
# Txn          213.0
# Name: 2022-08-23 13:09:00, dtype: float64
# Open      114400.0
# High      114410.0
# Low       114350.0
# Close     114370.0
# VWAP           0.0
# Volume       101.0
# Txn           46.0
# Name: 2022-08-23 13:11:00, dtype: float64
# Open      114320.0
# High      114420.0
# Low       114250.0
# Close     114420.0
# VWAP           0.0
# Volume       238.0
# Txn          145.0
# Name: 2022-08-23 13:17:00, dtype: float64
# Open      114440.0
# High      114450.0
# Low       114340.0
# Close     114450.0
# VWAP           0.0
# Volume       137.0
# Txn          106.0
# Name: 2022-08-23 13:20:00, dtype: float64
# Open      114860.0
# High      114890.0
# Low       114780.0
# Close     114810.0
# VWAP           0.0
# Volume       288.0
# Txn          169.0
# Name: 2022-08-23 13:25:00, dtype: float64
# Open      114850.0
# High      114860.0
# Low       114670.0
# Close     114690.0
# VWAP           0.0
# Volume       223.0
# Txn          133.0
# Name: 2022-08-23 13:28:00, dtype: float64
# Open      114800.0
# High      114830.0
# Low       114560.0
# Close     114630.0
# VWAP           0.0
# Volume       414.0
# Txn          226.0
# Name: 2022-08-23 13:30:00, dtype: float64
# Open      114690.0
# High      114690.0
# Low       114540.0
# Close     114590.0
# VWAP           0.0
# Volume        74.0
# Txn           62.0
# Name: 2022-08-23 13:32:00, dtype: float64
# Open      114570.0
# High      114580.0
# Low       114370.0
# Close     114370.0
# VWAP           0.0
# Volume       348.0
# Txn          199.0
# Name: 2022-08-23 13:33:00, dtype: float64
# Open      114600.0
# High      114680.0
# Low       114580.0
# Close     114580.0
# VWAP           0.0
# Volume        77.0
# Txn           56.0
# Name: 2022-08-23 13:38:00, dtype: float64
# Open      114580.0
# High      114580.0
# Low       114410.0
# Close     114500.0
# VWAP           0.0
# Volume       138.0
# Txn           98.0
# Name: 2022-08-23 13:39:00, dtype: float64
# Open      114490.0
# High      114490.0
# Low       114380.0
# Close     114420.0
# VWAP           0.0
# Volume       100.0
# Txn           69.0
# Name: 2022-08-23 13:40:00, dtype: float64
# Open      114410.0
# High      114410.0
# Low       114350.0
# Close     114350.0
# VWAP           0.0
# Volume       115.0
# Txn           49.0
# Name: 2022-08-23 13:44:00, dtype: float64
# Open      114580.0
# High      114710.0
# Low       114580.0
# Close     114710.0
# VWAP           0.0
# Volume       254.0
# Txn          187.0
# Name: 2022-08-23 13:48:00, dtype: float64
# Open      114700.0
# High      114730.0
# Low       114620.0
# Close     114700.0
# VWAP           0.0
# Volume       166.0
# Txn          109.0
# Name: 2022-08-23 13:49:00, dtype: float64
# Open      114700.0
# High      114740.0
# Low       114580.0
# Close     114580.0
# VWAP           0.0
# Volume       254.0
# Txn          203.0
# Name: 2022-08-23 13:50:00, dtype: float64
# Open      114550.0
# High      114580.0
# Low       114430.0
# Close     114520.0
# VWAP           0.0
# Volume       192.0
# Txn          108.0
# Name: 2022-08-23 13:56:00, dtype: float64
# Open      114500.0
# High      114540.0
# Low       114440.0
# Close     114440.0
# VWAP           0.0
# Volume        25.0
# Txn           20.0
# Name: 2022-08-23 13:58:00, dtype: float64
# Open      114620.0
# High      114750.0
# Low       114610.0
# Close     114750.0
# VWAP           0.0
# Volume       245.0
# Txn          130.0
# Name: 2022-08-23 14:10:00, dtype: float64
# Open      114730.0
# High      114740.0
# Low       114560.0
# Close     114600.0
# VWAP           0.0
# Volume       174.0
# Txn           95.0
# Name: 2022-08-23 14:11:00, dtype: float64
# Open      114830.0
# High      114920.0
# Low       114830.0
# Close     114860.0
# VWAP           0.0
# Volume       299.0
# Txn          178.0
# Name: 2022-08-23 14:23:00, dtype: float64
# Open      114880.0
# High      114890.0
# Low       114760.0
# Close     114780.0
# VWAP           0.0
# Volume       142.0
# Txn          101.0
# Name: 2022-08-23 14:24:00, dtype: float64
# Open      114750.0
# High      114840.0
# Low       114590.0
# Close     114660.0
# VWAP           0.0
# Volume       275.0
# Txn          195.0
# Name: 2022-08-23 14:27:00, dtype: float64
# Open      114650.0
# High      114750.0
# Low       114590.0
# Close     114710.0
# VWAP           0.0
# Volume       151.0
# Txn          104.0
# Name: 2022-08-23 14:28:00, dtype: float64
# Open      114710.0
# High      114750.0
# Low       114600.0
# Close     114640.0
# VWAP           0.0
# Volume       110.0
# Txn           84.0
# Name: 2022-08-23 14:29:00, dtype: float64
# Open      114640.0
# High      114640.0
# Low       114540.0
# Close     114550.0
# VWAP           0.0
# Volume        79.0
# Txn           65.0
# Name: 2022-08-23 14:39:00, dtype: float64
# Open      114550.0
# High      114610.0
# Low       114490.0
# Close     114570.0
# VWAP           0.0
# Volume       221.0
# Txn          116.0
# Name: 2022-08-23 14:40:00, dtype: float64
# Open      114500.0
# High      114680.0
# Low       114500.0
# Close     114660.0
# VWAP           0.0
# Volume        81.0
# Txn           69.0
# Name: 2022-08-23 14:45:00, dtype: float64
# Open      114610.0
# High      114630.0
# Low       114510.0
# Close     114610.0
# VWAP           0.0
# Volume       143.0
# Txn           97.0
# Name: 2022-08-23 14:49:00, dtype: float64
# Open      114690.0
# High      114690.0
# Low       114500.0
# Close     114510.0
# VWAP           0.0
# Volume       218.0
# Txn          145.0
# Name: 2022-08-23 15:06:00, dtype: float64
# Open      114500.0
# High      114570.0
# Low       114400.0
# Close     114490.0
# VWAP           0.0
# Volume       341.0
# Txn          186.0
# Name: 2022-08-23 15:07:00, dtype: float64
# Open      114560.0
# High      114580.0
# Low       114340.0
# Close     114390.0
# VWAP           0.0
# Volume       375.0
# Txn          210.0
# Name: 2022-08-23 15:22:00, dtype: float64
# Open      114390.0
# High      114440.0
# Low       114300.0
# Close     114430.0
# VWAP           0.0
# Volume       189.0
# Txn           99.0
# Name: 2022-08-23 15:23:00, dtype: float64
# Open      114430.0
# High      114430.0
# Low       114210.0
# Close     114260.0
# VWAP           0.0
# Volume       323.0
# Txn          207.0
# Name: 2022-08-23 15:26:00, dtype: float64
# Open      114270.0
# High      114290.0
# Low       114180.0
# Close     114220.0
# VWAP           0.0
# Volume       221.0
# Txn          132.0
# Name: 2022-08-23 15:28:00, dtype: float64
# Open      114200.0
# High      114230.0
# Low       114120.0
# Close     114150.0
# VWAP           0.0
# Volume       116.0
# Txn           87.0
# Name: 2022-08-23 15:31:00, dtype: float64
# Open      114200.0
# High      114240.0
# Low       114050.0
# Close     114050.0
# VWAP           0.0
# Volume       180.0
# Txn          134.0
# Name: 2022-08-23 15:35:00, dtype: float64
# Open      114030.0
# High      114080.0
# Low       114010.0
# Close     114080.0
# VWAP           0.0
# Volume       132.0
# Txn           77.0
# Name: 2022-08-23 15:38:00, dtype: float64
# Open      114130.0
# High      114140.0
# Low       114010.0
# Close     114090.0
# VWAP           0.0
# Volume        80.0
# Txn           53.0
# Name: 2022-08-23 15:42:00, dtype: float64
# Open      114080.0
# High      114090.0
# Low       113960.0
# Close     113960.0
# VWAP           0.0
# Volume       182.0
# Txn          124.0
# Name: 2022-08-23 15:43:00, dtype: float64
# Open      114030.0
# High      114090.0
# Low       113880.0
# Close     113880.0
# VWAP           0.0
# Volume       622.0
# Txn          336.0
# Name: 2022-08-23 15:45:00, dtype: float64
# Open      114100.0
# High      114240.0
# Low       114090.0
# Close     114190.0
# VWAP           0.0
# Volume       416.0
# Txn          223.0
# Name: 2022-08-23 15:47:00, dtype: float64
# Open      114190.0
# High      114220.0
# Low       114120.0
# Close     114200.0
# VWAP           0.0
# Volume       170.0
# Txn          110.0
# Name: 2022-08-23 15:48:00, dtype: float64
# Open      114480.0
# High      114530.0
# Low       114420.0
# Close     114510.0
# VWAP           0.0
# Volume       248.0
# Txn          137.0
# Name: 2022-08-23 15:58:00, dtype: float64
# Open      114560.0
# High      114580.0
# Low       114400.0
# Close     114410.0
# VWAP           0.0
# Volume       191.0
# Txn          117.0
# Name: 2022-08-23 16:00:00, dtype: float64
# Open      114410.0
# High      114420.0
# Low       114330.0
# Close     114330.0
# VWAP           0.0
# Volume       157.0
# Txn           98.0
# Name: 2022-08-23 16:01:00, dtype: float64
# Open      114350.0
# High      114370.0
# Low       114150.0
# Close     114250.0
# VWAP           0.0
# Volume       336.0
# Txn          225.0
# Name: 2022-08-23 16:02:00, dtype: float64
# Open      114360.0
# High      114380.0
# Low       114120.0
# Close     114200.0
# VWAP           0.0
# Volume       205.0
# Txn          126.0
# Name: 2022-08-23 16:10:00, dtype: float64
# Open      114180.0
# High      114200.0
# Low       114070.0
# Close     114090.0
# VWAP           0.0
# Volume        92.0
# Txn           79.0
# Name: 2022-08-23 16:12:00, dtype: float64
# Open      114330.0
# High      114440.0
# Low       114320.0
# Close     114440.0
# VWAP           0.0
# Volume       102.0
# Txn           73.0
# Name: 2022-08-23 16:18:00, dtype: float64
# Open      114450.0
# High      114450.0
# Low       114360.0
# Close     114360.0
# VWAP           0.0
# Volume        86.0
# Txn           77.0
# Name: 2022-08-23 16:19:00, dtype: float64
# Open      114340.0
# High      114370.0
# Low       114170.0
# Close     114190.0
# VWAP           0.0
# Volume       138.0
# Txn          107.0
# Name: 2022-08-23 16:20:00, dtype: float64
# Open      114240.0
# High      114250.0
# Low       114080.0
# Close     114080.0
# VWAP           0.0
# Volume       568.0
# Txn          245.0
# Name: 2022-08-23 16:29:00, dtype: float64
# Open      114080.0
# High      114170.0
# Low       113950.0
# Close     114040.0
# VWAP           0.0
# Volume       597.0
# Txn          328.0
# Name: 2022-08-23 16:30:00, dtype: float64
# Open      114040.0
# High      114060.0
# Low       113960.0
# Close     113960.0
# VWAP           0.0
# Volume       182.0
# Txn          113.0
# Name: 2022-08-23 16:31:00, dtype: float64
# Open      113960.0
# High      114030.0
# Low       113900.0
# Close     113940.0
# VWAP           0.0
# Volume       954.0
# Txn          464.0
# Name: 2022-08-23 16:32:00, dtype: float64
# Open      114270.0
# High      114290.0
# Low       114210.0
# Close     114230.0
# VWAP           0.0
# Volume        78.0
# Txn           52.0
# Name: 2022-08-23 16:37:00, dtype: float64
# Open      114240.0
# High      114250.0
# Low       114170.0
# Close     114170.0
# VWAP           0.0
# Volume        90.0
# Txn           70.0
# Name: 2022-08-23 16:38:00, dtype: float64
# Open      114400.0
# High      114550.0
# Low       114340.0
# Close     114530.0
# VWAP           0.0
# Volume       177.0
# Txn          134.0
# Name: 2022-08-23 16:43:00, dtype: float64
# Open      114620.0
# High      114670.0
# Low       114470.0
# Close     114470.0
# VWAP           0.0
# Volume       256.0
# Txn          153.0
# Name: 2022-08-23 16:45:00, dtype: float64
# Open      114530.0
# High      114530.0
# Low       114360.0
# Close     114370.0
# VWAP           0.0
# Volume       349.0
# Txn          189.0
# Name: 2022-08-23 17:01:00, dtype: float64
# Open      114580.0
# High      114800.0
# Low       114550.0
# Close     114800.0
# VWAP           0.0
# Volume       460.0
# Txn          244.0
# Name: 2022-08-23 17:03:00, dtype: float64
# Open      114840.0
# High      114890.0
# Low       114730.0
# Close     114770.0
# VWAP           0.0
# Volume       214.0
# Txn          138.0
# Name: 2022-08-23 17:05:00, dtype: float64
# Open      114780.0
# High      114790.0
# Low       114700.0
# Close     114710.0
# VWAP           0.0
# Volume       104.0
# Txn           73.0
# Name: 2022-08-23 17:09:00, dtype: float64
# Open      114730.0
# High      114750.0
# Low       114650.0
# Close     114670.0
# VWAP           0.0
# Volume        81.0
# Txn           57.0
# Name: 2022-08-23 17:10:00, dtype: float64
# Open      114600.0
# High      114640.0
# Low       114600.0
# Close     114640.0
# VWAP           0.0
# Volume        43.0
# Txn           29.0
# Name: 2022-08-23 17:39:00, dtype: float64
# Open      114840.0
# High      114980.0
# Low       114830.0
# Close     114870.0
# VWAP           0.0
# Volume       517.0
# Txn          302.0
# Name: 2022-08-23 17:50:00, dtype: float64
# Open      115030.0
# High      115180.0
# Low       115030.0
# Close     115160.0
# VWAP           0.0
# Volume       163.0
# Txn          106.0
# Name: 2022-08-23 17:58:00, dtype: float64
# Open      115160.0
# High      115190.0
# Low       115080.0
# Close     115100.0
# VWAP           0.0
# Volume       176.0
# Txn          116.0
# Name: 2022-08-23 17:59:00, dtype: float64
# Open      115170.0
# High      115170.0
# Low       115000.0
# Close     115000.0
# VWAP           0.0
# Volume       137.0
# Txn          108.0
# Name: 2022-08-23 18:02:00, dtype: float64
# Open      114980.0
# High      114990.0
# Low       114920.0
# Close     114930.0
# VWAP           0.0
# Volume       102.0
# Txn           71.0
# Name: 2022-08-23 18:17:00, dtype: float64
# Open      115000.0
# High      115020.0
# Low       114830.0
# Close     114870.0
# VWAP           0.0
# Volume       379.0
# Txn          247.0
# Name: 2022-08-23 18:39:00, dtype: float64
# Open      114870.0
# High      114900.0
# Low       114800.0
# Close     114810.0
# VWAP           0.0
# Volume       143.0
# Txn           90.0
# Name: 2022-08-23 18:40:00, dtype: float64
# Open      114750.0
# High      114750.0
# Low       114700.0
# Close     114700.0
# VWAP           0.0
# Volume        89.0
# Txn           54.0
# Name: 2022-08-23 18:43:00, dtype: float64
# Open      114630.0
# High      114690.0
# Low       114530.0
# Close     114680.0
# VWAP           0.0
# Volume       128.0
# Txn           70.0
# Name: 2022-08-23 19:05:00, dtype: float64
# Open      114680.0
# High      114720.0
# Low       114620.0
# Close     114700.0
# VWAP           0.0
# Volume        33.0
# Txn           31.0
# Name: 2022-08-23 19:06:00, dtype: float64
# Open      114710.0
# High      114730.0
# Low       114620.0
# Close     114640.0
# VWAP           0.0
# Volume        53.0
# Txn           30.0
# Name: 2022-08-23 19:07:00, dtype: float64
# Open      114930.0
# High      114950.0
# Low       114920.0
# Close     114920.0
# VWAP           0.0
# Volume        19.0
# Txn           14.0
# Name: 2022-08-23 22:33:00, dtype: float64
# Open      114900.0
# High      114900.0
# Low       114800.0
# Close     114830.0
# VWAP           0.0
# Volume        55.0
# Txn           31.0
# Name: 2022-08-23 22:42:00, dtype: float64
# Open      114800.0
# High      114810.0
# Low       114770.0
# Close     114790.0
# VWAP           0.0
# Volume        25.0
# Txn           15.0
# Name: 2022-08-23 23:16:00, dtype: float64
# Start                     2022-08-19 10:00:00
# End                       2022-08-23 23:49:00
# Duration                      4 days 13:49:00
# Exposure Time [%]                   97.463538
# Equity Final [$]                   9933418.08
# Equity Peak [$]                    10000000.0
# Return [%]                          -0.665819
# Buy & Hold Return [%]                2.730528
# Return (Ann.) [%]                  -34.379309
# Volatility (Ann.) [%]                     NaN
# Sharpe Ratio                              NaN
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                   -0.666619
# Avg. Drawdown [%]                   -0.666619
# Max. Drawdown Duration        4 days 13:48:00
# Avg. Drawdown Duration        4 days 13:48:00
# # Trades                                  321
# Win Rate [%]                        19.003115
# Best Trade [%]                       0.759421
# Worst Trade [%]                      -0.28851
# Avg. Trade [%]                      -0.183517
# Max. Trade Duration           3 days 10:36:00
# Avg. Trade Duration           0 days 00:20:00
# Profit Factor                        0.071507
# Expectancy [%]                      -0.183431
# SQN                                -24.996252
# _strategy                          MLStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %%
bt.plot()

# %%
# %%time

stats = bt.optimize(n1=range(5, 30, 5),
                    n2=range(10, 70, 5),
                    maximize='Equity Final [$]',
                    constraint=lambda param: param.n1 < param.n2)
stats

# %%
stats._strategy

# %%
bt.plot(plot_volume=False, plot_pl=False)

# %%
stats.tail()

# %%
stats['_equity_curve']  # Contains equity/drawdown curves. DrawdownDuration is only defined at ends of DD periods.

# %%
stats['_trades']  # Contains individual trade data
